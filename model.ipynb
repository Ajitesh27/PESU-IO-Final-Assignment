# %%
#Average accuracy is : 0.9973
def code():
    x = df.drop(['RainTomorrow','Evaporation','Sunshine','WindGustDir','WindDir9am','WindDir3pm','Location','Date'], axis=1)
    y = df['RainTomorrow']
    x_train, x_test, y_train, y_test = train_test_split(x, y,train_size=0.8,test_size=0.2, random_state=1)
    predictions = logmodel.predict(x_test)
    accuracy.append(accuracy_score(y_test, predictions))


cities=['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree', 'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond', 'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown', 'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat', 'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura', 'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns', 'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa', 'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport', 'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston', 'AliceSprings', 'Darwin', 'Katherine', 'Uluru']
accuracy=[]
b=0;
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score

df1=pd.DataFrame()
for a in cities:
    filename=a+'.csv'
    df_temp=pd.read_csv(filename)
    df1=pd.concat([df1,df_temp])
    
df1.replace(' Yes','1',inplace=True)
df1.replace(' No','0',inplace=True)
df1.replace(' nan','0',inplace=True)

#Below is the training of the model with the complete data set
x1 = df1.drop(['RainTomorrow','Evaporation','Sunshine','WindGustDir','WindDir9am','WindDir3pm','Location','Date'], axis=1)
y1 = df1['RainTomorrow']
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1,train_size=0.8,test_size=0.2, random_state=1)
logmodel = LogisticRegression(solver='liblinear')
logmodel.fit(x_train1, y_train1)

    
for a in cities:
    filename=a+'.csv'
    df=pd.read_csv(filename)
    df.replace(' Yes','1',inplace=True)
    df.replace(' No','0',inplace=True)
    df.replace(' nan','0',inplace=True)
    code()
    print('Test on',filename,'Accuracy:',accuracy[b])
    b+=1
    
print('Average accuracy:',sum(accuracy)/49)
# Out:
# Test on Albury.csv Accuracy: 0.9983416252072969
# Test on BadgerysCreek.csv Accuracy: 1.0
# Test on Cobar.csv Accuracy: 1.0
# Test on CoffsHarbour.csv Accuracy: 0.9966159052453468
# Test on Moree.csv Accuracy: 0.9964973730297724
# Test on Newcastle.csv Accuracy: 0.988155668358714
# Test on NorahHead.csv Accuracy: 1.0
# Test on NorfolkIsland.csv Accuracy: 0.9915682967959528
# Test on Penrith.csv Accuracy: 1.0
# Test on Richmond.csv Accuracy: 0.9966159052453468
# Test on Sydney.csv Accuracy: 1.0
# Test on SydneyAirport.csv Accuracy: 0.9933444259567388
# Test on WaggaWagga.csv Accuracy: 1.0
# Test on Williamtown.csv Accuracy: 0.9980430528375733
# Test on Wollongong.csv Accuracy: 0.9932998324958124
# Test on Canberra.csv Accuracy: 0.9985380116959064
# Test on Tuggeranong.csv Accuracy: 0.9983333333333333
# Test on MountGinini.csv Accuracy: 0.9982817869415808
# Test on Ballarat.csv Accuracy: 0.9933993399339934
# Test on Bendigo.csv Accuracy: 1.0
# ...
